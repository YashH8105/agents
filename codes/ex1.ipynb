# %%
# !ollama pull llama3.2
# Out:
# 'ollama' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from openai import OpenAI

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")

# %%
question = "pick an industry which might have some agentic ai exploring opportunity"
message = [{"role" : "user", "content" : question}]

# %%
response =ollama.chat.completions.create(
    model="llama3.2",
    messages=message
)

question = response.choices[0].message.content
print(question)
# Out:
# Let's take the industry of Healthcare as an example. Healthcare is an area where Agentic AI (Artificial General Intelligence) could potentially have a significant impact.
#
# Agentic AI refers to AI systems that can make decisions, act on their own, and adapt to changing situations, much like humans do. In healthcare, this could translate to AI systems being able to:
#
# 1. Diagnose complex medical conditions autonomously: With access to vast amounts of medical data, Agentic AI could analyze patient histories, symptoms, and test results to make accurate diagnoses without human oversight.
# 2. Develop personalized treatment plans: By analyzing genetic profiles, medical history, and lifestyle factors, Agentic AI could create tailored treatment plans for each patient, including medication regimens, dosages, and monitoring schedules.
# 3. Administer care remotely: Using mobile devices or wearables, Agentic AI-powered robots or virtual assistants could remotely monitor patients with chronic conditions, detect early warning signs of complications, and even administer basic treatments.
# 4. Optimize hospital operations: By analyzing operational data, patient flow, and supply chain logistics, Agentric might be able to identify opportunities for process improvements, reduced waste, enhanced efficiency, reduced costs.
#
# However we still have lots of challenges such as explaining medical diagnosis results, developing trust with humans in the system and dealing with bias
